# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
# import matplotlib.pyplot as plt
# import pandas as pd
# import numpy as np
# import requests
# import time
# from scipy.stats import linregress
# import citypy

# Workaround to fix Citipy issue.  Performed a pip install citipy and still would not work with original code.
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime
from scipy.stats import linregress
import scipy.stats as st
from pandas import DataFrame
from requests import get 

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file_cities = "output/cities.csv"

# Range of latitudes and longitudes
lat_range = (0, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
#len(cities)
#print(cities)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Use url from class, ensure API Key is working, and convert temps to imperial (Fahrenheit)
url = 'http://api.openweathermap.org/data/2.5/weather?&units=imperial&'  # To convert to Fahrenheit, I needed to have a workaround where I placed the & after imperial.  Otherwise, the temps are not converted correctly
#url = 'http://api.openweathermap.org/data/2.5/weather?'
#units = 'imperial'
api_key = '28c4ccd34ec2c4e49331c9c55008fd8b'   # My API key

# Test url to determine it works
#http://api.openweathermap.org/data/2.5/weather?&APPID=28c4ccd34ec2c4e49331c9c55008fd8b&units=imperial&q=chicago

# Create query_url
#query_url = url + "&appid=" + api_key + "&units=" + units + "&q=" + city

query_url = url + "appid=" + api_key + "&q=" + city
#print(query_url)

#type(query_url)  # Check type

# %%
# Set up a test of cities in list to iterate in the For Loop
#cities = ['London', 'notA_city', 'Chicago', 'Tokyo', 'Toronto', 'Orlando', 'Miami', 'Moscow', 'Hong Kong', 'Shanghai', 'Seoul', 'Paris', 'New York City']

# Initiate a list (columns) to hold reponses in a df
temp = []
humidity = []
cloudiness = []
wind_speed = []
lngs = []
lats = []
city_name = []

# %%
# Use a For Loop to iterate through cities

for city in cities:
    try:
        query_url = url + "appid=" + api_key + "&q=" + city
        weather_dict = get(query_url).json()     
        if 'coord' in weather_dict:
            print('found', city)
        else:
            print(city, 'not found')
        lats.append(weather_dict['coord']['lat'])  # Append to list for each key/item found in weather_dict
        lngs.append(weather_dict['coord']['lon'])
        humidity.append(weather_dict['main']['humidity'])
        cloudiness.append(weather_dict['clouds']['all'])
        wind_speed.append(weather_dict['wind']['speed'])
        temp.append(weather_dict['main']['temp'])
        city_name.append(city)
    except Exception as e:
        print('Something broke...', e)
    finally:
        print('Finished trying to get', city)

city_name.to_csv("./output/cities.csv", index=False)
# Out:
# found sisimiut
# Finished trying to get sisimiut
# found sur
# Finished trying to get sur
# found mandera
# Finished trying to get mandera
# found hasaki
# Finished trying to get hasaki
# found pangody
# Finished trying to get pangody
# found new milford
# Finished trying to get new milford
# barentsburg not found
# Something broke... 'coord'
# Finished trying to get barentsburg
# found makakilo city
# Finished trying to get makakilo city
# found zverinogolovskoye
# Finished trying to get zverinogolovskoye
# found dingle
# Finished trying to get dingle
# nizhneyansk not found
# Something broke... 'coord'
# Finished trying to get nizhneyansk
# found magalia
# Finished trying to get magalia
# found hilo
# Finished trying to get hilo
# found whitecourt
# Finished trying to get whitecourt
# found kirtipur
# Finished trying to get kirtipur
# found la ronge
# Finished trying to get la ronge
# found nanortalik
# Finished trying to get nanortalik
# found hobyo
# Finished trying to get hobyo
# found marmora
# Finished trying to get marmora
# found atar
# Finished trying to get atar
# found aklavik
# Finished trying to get aklavik
# illoqqortoormiut not found
# Something broke... 'coord'
# Finished trying to get illoqqortoormiut
# found ribeira grande
# Finished trying to get ribeira grande
# found nakamura
# Finished trying to get nakamura
# found leon
# Finished trying to get leon
# found baisha
# Finished trying to get baisha
# found dikson
# Finished trying to get dikson
# found vrangel
# Finished trying to get vrangel
# found iqaluit
# Finished trying to get iqaluit
# found pevek
# Finished trying to get pevek
# found umm kaddadah
# Finished trying to get umm kaddadah
# found san andres
# Finished trying to get san andres
# sentyabrskiy not found
# Something broke... 'coord'
# Finished trying to get sentyabrskiy
# found yashalta
# Finished trying to get yashalta
# found paoua
# Finished trying to get paoua
# found lompoc
# Finished trying to get lompoc
# found havoysund
# Finished trying to get havoysund
# found khatanga
# Finished trying to get khatanga
# found airai
# Finished trying to get airai
# found butaritari
# Finished trying to get butaritari
# found marawi
# Finished trying to get marawi
# found tuktoyaktuk
# Finished trying to get tuktoyaktuk
# found oktyabrskiy
# Finished trying to get oktyabrskiy
# found ponta do sol
# Finished trying to get ponta do sol
# found raudeberg
# Finished trying to get raudeberg
# found perelyub
# Finished trying to get perelyub
# found barrow
# Finished trying to get barrow
# found upernavik
# Finished trying to get upernavik
# found kapaa
# Finished trying to get kapaa
# found vila franca do campo
# Finished trying to get vila franca do campo
# found fort-shevchenko
# Finished trying to get fort-shevchenko
# found kuandian
# Finished trying to get kuandian
# found saint-francois
# Finished trying to get saint-francois
# found kodiak
# Finished trying to get kodiak
# attawapiskat not found
# Something broke... 'coord'
# Finished trying to get attawapiskat
# found klaksvik
# Finished trying to get klaksvik
# found bousse
# Finished trying to get bousse
# found tasiilaq
# Finished trying to get tasiilaq
# found tenenkou
# Finished trying to get tenenkou
# found sretensk
# Finished trying to get sretensk
# found qaanaaq
# Finished trying to get qaanaaq
# found saskylakh
# Finished trying to get saskylakh
# found sidi ali
# Finished trying to get sidi ali
# found eldorado
# Finished trying to get eldorado
# found trairi
# Finished trying to get trairi
# found kailua
# Finished trying to get kailua
# amderma not found
# Something broke... 'coord'
# Finished trying to get amderma
# found big spring
# Finished trying to get big spring
# belushya guba not found
# Something broke... 'coord'
# Finished trying to get belushya guba
# found koygorodok
# Finished trying to get koygorodok
# found porto novo
# Finished trying to get porto novo
# found kavieng
# Finished trying to get kavieng
# found yellowknife
# Finished trying to get yellowknife
# found tiksi
# Finished trying to get tiksi
# found port blair
# Finished trying to get port blair
# found zhezkazgan
# Finished trying to get zhezkazgan
# found andippatti
# Finished trying to get andippatti
# mrirt not found
# Something broke... 'coord'
# Finished trying to get mrirt
# found churapcha
# Finished trying to get churapcha
# bolungarvik not found
# Something broke... 'coord'
# Finished trying to get bolungarvik
# ondorhaan not found
# Something broke... 'coord'
# Finished trying to get ondorhaan
# found zdvinsk
# Finished trying to get zdvinsk
# found fortuna
# Finished trying to get fortuna
# found cerea
# Finished trying to get cerea
# found stuttgart
# Finished trying to get stuttgart
# found bolgatanga
# Finished trying to get bolgatanga
# found severo-kurilsk
# Finished trying to get severo-kurilsk
# found lavrentiya
# Finished trying to get lavrentiya
# found koshurnikovo
# Finished trying to get koshurnikovo
# found cabo san lucas
# Finished trying to get cabo san lucas
# found torbay
# Finished trying to get torbay
# found bilma
# Finished trying to get bilma
# found baghdad
# Finished trying to get baghdad
# found polunochnoye
# Finished trying to get polunochnoye
# found dawei
# Finished trying to get dawei
# found ucluelet
# Finished trying to get ucluelet
# found okhotsk
# Finished trying to get okhotsk
# found madera
# Finished trying to get madera
# found tukrah
# Finished trying to get tukrah
# found berlevag
# Finished trying to get berlevag
# found paamiut
# Finished trying to get paamiut
# found kita
# Finished trying to get kita
# found ziyang
# Finished trying to get ziyang
# found baruun-urt
# Finished trying to get baruun-urt
# found yeniseysk
# Finished trying to get yeniseysk
# found bethel
# Finished trying to get bethel
# found nikolskoye
# Finished trying to get nikolskoye
# found komsomolskiy
# Finished trying to get komsomolskiy
# found turbat
# Finished trying to get turbat
# found narsaq
# Finished trying to get narsaq
# found cayenne
# Finished trying to get cayenne
# found port hardy
# Finished trying to get port hardy
# found pozoblanco
# Finished trying to get pozoblanco
# found qaqortoq
# Finished trying to get qaqortoq
# found puerto del rosario
# Finished trying to get puerto del rosario
# found leningradskiy
# Finished trying to get leningradskiy
# found nantucket
# Finished trying to get nantucket
# found talnakh
# Finished trying to get talnakh
# found lorengau
# Finished trying to get lorengau
# found nevers
# Finished trying to get nevers
# found egvekinot
# Finished trying to get egvekinot
# found saint george
# Finished trying to get saint george
# found ha giang
# Finished trying to get ha giang
# found lang son
# Finished trying to get lang son
# found lanxi
# Finished trying to get lanxi
# found haimen
# Finished trying to get haimen
# found kuytun
# Finished trying to get kuytun
# found catuday
# Finished trying to get catuday
# found nadym
# Finished trying to get nadym
# tasbuget not found
# Something broke... 'coord'
# Finished trying to get tasbuget
# found sao filipe
# Finished trying to get sao filipe
# found clyde river
# Finished trying to get clyde river
# longlac not found
# Something broke... 'coord'
# Finished trying to get longlac
# found kavaratti
# Finished trying to get kavaratti
# found kalmunai
# Finished trying to get kalmunai
# found bay roberts
# Finished trying to get bay roberts
# found yanam
# Finished trying to get yanam
# found ballina
# Finished trying to get ballina
# found kudahuvadhoo
# Finished trying to get kudahuvadhoo
# found darhan
# Finished trying to get darhan
# found erzurum
# Finished trying to get erzurum
# found yugorsk
# Finished trying to get yugorsk
# found puerto ayora
# Finished trying to get puerto ayora
# found marienburg
# Finished trying to get marienburg
# found bontang
# Finished trying to get bontang
# found jijiang
# Finished trying to get jijiang
# found ulaangom
# Finished trying to get ulaangom
# found longyearbyen
# Finished trying to get longyearbyen
# mys shmidta not found
# Something broke... 'coord'
# Finished trying to get mys shmidta
# saleaula not found
# Something broke... 'coord'
# Finished trying to get saleaula
# found kieta
# Finished trying to get kieta
# found vardo
# Finished trying to get vardo
# found kochevo
# Finished trying to get kochevo
# found chokurdakh
# Finished trying to get chokurdakh
# found acajutla
# Finished trying to get acajutla
# found truro
# Finished trying to get truro
# found norman wells
# Finished trying to get norman wells
# found kahului
# Finished trying to get kahului
# found lozova
# Finished trying to get lozova
# found kolondieba
# Finished trying to get kolondieba
# found tashtyp
# Finished trying to get tashtyp
# found chojnice
# Finished trying to get chojnice
# found acapulco
# Finished trying to get acapulco
# found poltsamaa
# Finished trying to get poltsamaa
# found pawai
# Finished trying to get pawai
# found tezu
# Finished trying to get tezu
# found mayo
# Finished trying to get mayo
# found zeya
# Finished trying to get zeya
# found podor
# Finished trying to get podor
# found college
# Finished trying to get college
# found deputatskiy
# Finished trying to get deputatskiy
# found ayan
# Finished trying to get ayan
# found kande
# Finished trying to get kande
# found oceanside
# Finished trying to get oceanside
# found thinadhoo
# Finished trying to get thinadhoo
# found nemuro
# Finished trying to get nemuro
# found itoman
# Finished trying to get itoman
# sinkat not found
# Something broke... 'coord'
# Finished trying to get sinkat
# found vostok
# Finished trying to get vostok
# found kautokeino
# Finished trying to get kautokeino
# found arlit
# Finished trying to get arlit
# found dudinka
# Finished trying to get dudinka
# found lesce
# Finished trying to get lesce
# found anamur
# Finished trying to get anamur
# found belyy yar
# Finished trying to get belyy yar
# found mogadishu
# Finished trying to get mogadishu
# found sept-iles
# Finished trying to get sept-iles
# found cravo norte
# Finished trying to get cravo norte
# found north bend
# Finished trying to get north bend
# found nuuk
# Finished trying to get nuuk
# found bubaque
# Finished trying to get bubaque
# found naron
# Finished trying to get naron
# found igarka
# Finished trying to get igarka
# found grindavik
# Finished trying to get grindavik
# found bondo
# Finished trying to get bondo
# found duldurga
# Finished trying to get duldurga
# found acarau
# Finished trying to get acarau
# found agirish
# Finished trying to get agirish
# found sitka
# Finished trying to get sitka
# found luxor
# Finished trying to get luxor
# found kirs
# Finished trying to get kirs
# found price
# Finished trying to get price
# found saint-augustin
# Finished trying to get saint-augustin
# found thompson
# Finished trying to get thompson
# found brownwood
# Finished trying to get brownwood
# found san patricio
# Finished trying to get san patricio
# found monrovia
# Finished trying to get monrovia
# found fukue
# Finished trying to get fukue
# found flin flon
# Finished trying to get flin flon
# found dire dawa
# Finished trying to get dire dawa
# found bandarbeyla
# Finished trying to get bandarbeyla
# found weyburn
# Finished trying to get weyburn
# found atuona
# Finished trying to get atuona
# found aksay
# Finished trying to get aksay
# found liverpool
# Finished trying to get liverpool
# found orlik
# Finished trying to get orlik
# found ponta delgada
# Finished trying to get ponta delgada
# found wilmington
# Finished trying to get wilmington
# found shahrud
# Finished trying to get shahrud
# found kloulklubed
# Finished trying to get kloulklubed
# haibowan not found
# Something broke... 'coord'
# Finished trying to get haibowan
# found sobolevo
# Finished trying to get sobolevo
# tumannyy not found
# Something broke... 'coord'
# Finished trying to get tumannyy
# found bagn
# Finished trying to get bagn
# found ugoofaaru
# Finished trying to get ugoofaaru
# found yerbogachen
# Finished trying to get yerbogachen
# found gat
# Finished trying to get gat
# found lagoa
# Finished trying to get lagoa
# found alakurtti
# Finished trying to get alakurtti
# found inndyr
# Finished trying to get inndyr
# found fort nelson
# Finished trying to get fort nelson
# found porto torres
# Finished trying to get porto torres
# found cherskiy
# Finished trying to get cherskiy
# found bud
# Finished trying to get bud
# found lakselv
# Finished trying to get lakselv
# found mikkeli
# Finished trying to get mikkeli
# found kralendijk
# Finished trying to get kralendijk
# found pitea
# Finished trying to get pitea
# found tura
# Finished trying to get tura
# found plyussa
# Finished trying to get plyussa
# found saint anthony
# Finished trying to get saint anthony
# found vestmannaeyjar
# Finished trying to get vestmannaeyjar
# found evensk
# Finished trying to get evensk
# found baykit
# Finished trying to get baykit
# found etchoropo
# Finished trying to get etchoropo
# found balkanabat
# Finished trying to get balkanabat
# found pyapon
# Finished trying to get pyapon
# found ocos
# Finished trying to get ocos
# found borogontsy
# Finished trying to get borogontsy
# found vendome
# Finished trying to get vendome
# found yarega
# Finished trying to get yarega
# found clarksville
# Finished trying to get clarksville
# found rudnichnyy
# Finished trying to get rudnichnyy
# found moose factory
# Finished trying to get moose factory
# found harnosand
# Finished trying to get harnosand
# found lasa
# Finished trying to get lasa
# found oranjestad
# Finished trying to get oranjestad
# found wattegama
# Finished trying to get wattegama
# found olafsvik
# Finished trying to get olafsvik
# found kosh-agach
# Finished trying to get kosh-agach
# found abu dhabi
# Finished trying to get abu dhabi
# found mut
# Finished trying to get mut
# found teya
# Finished trying to get teya
# found centralia
# Finished trying to get centralia
# found bathsheba
# Finished trying to get bathsheba
# found illela
# Finished trying to get illela
# found faranah
# Finished trying to get faranah
# found west odessa
# Finished trying to get west odessa
# found kropotkin
# Finished trying to get kropotkin
# found jumla
# Finished trying to get jumla
# found santa maria
# Finished trying to get santa maria
# found hirara
# Finished trying to get hirara
# found vidim
# Finished trying to get vidim
# found zhangye
# Finished trying to get zhangye
# found minsk
# Finished trying to get minsk
# found thanh hoa
# Finished trying to get thanh hoa
# found west plains
# Finished trying to get west plains
# found taoudenni
# Finished trying to get taoudenni
# found murdochville
# Finished trying to get murdochville
# found shu
# Finished trying to get shu
# found sturgis
# Finished trying to get sturgis
# found leshukonskoye
# Finished trying to get leshukonskoye
# found kologriv
# Finished trying to get kologriv
# found victoria
# Finished trying to get victoria
# found praia da vitoria
# Finished trying to get praia da vitoria
# found san vicente
# Finished trying to get san vicente
# found robertsport
# Finished trying to get robertsport
# found lac du bonnet
# Finished trying to get lac du bonnet
# found san jose
# Finished trying to get san jose
# found strezhevoy
# Finished trying to get strezhevoy
# found sabya
# Finished trying to get sabya
# found kyzyl-suu
# Finished trying to get kyzyl-suu
# found kuching
# Finished trying to get kuching
# found buenos aires
# Finished trying to get buenos aires
# found aljezur
# Finished trying to get aljezur
# found nome
# Finished trying to get nome
# meyungs not found
# Something broke... 'coord'
# Finished trying to get meyungs
# found ostrovnoy
# Finished trying to get ostrovnoy
# found naze
# Finished trying to get naze
# found bulgan
# Finished trying to get bulgan
# found karakol
# Finished trying to get karakol
# found nandu
# Finished trying to get nandu
# found milford
# Finished trying to get milford
# jiddah not found
# Something broke... 'coord'
# Finished trying to get jiddah
# found tessaoua
# Finished trying to get tessaoua
# found vanimo
# Finished trying to get vanimo
# found bhatgaon
# Finished trying to get bhatgaon
# found korla
# Finished trying to get korla
# found abu kamal
# Finished trying to get abu kamal
# found hami
# Finished trying to get hami
# found nizhniy kuranakh
# Finished trying to get nizhniy kuranakh
# found kamaishi
# Finished trying to get kamaishi
# found alcaniz
# Finished trying to get alcaniz
# found badami
# Finished trying to get badami
# found kyra
# Finished trying to get kyra
# found hansi
# Finished trying to get hansi
# found nouadhibou
# Finished trying to get nouadhibou
# found korsakovo
# Finished trying to get korsakovo
# found fairbanks
# Finished trying to get fairbanks
# found yumen
# Finished trying to get yumen
# found faya
# Finished trying to get faya
# found havre-saint-pierre
# Finished trying to get havre-saint-pierre
# found eden
# Finished trying to get eden
# found husavik
# Finished trying to get husavik
# found luba
# Finished trying to get luba
# found mae sai
# Finished trying to get mae sai
# found salalah
# Finished trying to get salalah
# found hofn
# Finished trying to get hofn
# found barahona
# Finished trying to get barahona
# found qom
# Finished trying to get qom
# found bembereke
# Finished trying to get bembereke
# found mehamn
# Finished trying to get mehamn
# hunza not found
# Something broke... 'coord'
# Finished trying to get hunza
# found bechem
# Finished trying to get bechem
# found timra
# Finished trying to get timra
# found bridlington
# Finished trying to get bridlington
# found brownsville
# Finished trying to get brownsville
# found banda aceh
# Finished trying to get banda aceh
# found gua musang
# Finished trying to get gua musang
# found hovd
# Finished trying to get hovd
# found zhigansk
# Finished trying to get zhigansk
# found sakakah
# Finished trying to get sakakah
# found hay river
# Finished trying to get hay river
# found shimoda
# Finished trying to get shimoda
# found roald
# Finished trying to get roald
# found pershotravneve
# Finished trying to get pershotravneve
# found springdale
# Finished trying to get springdale
# found ilulissat
# Finished trying to get ilulissat
# found konstantinovka
# Finished trying to get konstantinovka
# found datong
# Finished trying to get datong
# found celestun
# Finished trying to get celestun
# found tibati
# Finished trying to get tibati
# found dharapuram
# Finished trying to get dharapuram
# found arteaga
# Finished trying to get arteaga
# found adre
# Finished trying to get adre
# found aleksandrovsk-sakhalinskiy
# Finished trying to get aleksandrovsk-sakhalinskiy
# found jalu
# Finished trying to get jalu
# found mahon
# Finished trying to get mahon
# found zyryanka
# Finished trying to get zyryanka
# found marabba
# Finished trying to get marabba
# found westport
# Finished trying to get westport
# found beringovskiy
# Finished trying to get beringovskiy
# found shakhtinsk
# Finished trying to get shakhtinsk
# found yishui
# Finished trying to get yishui
# grand centre not found
# Something broke... 'coord'
# Finished trying to get grand centre
# found gorontalo
# Finished trying to get gorontalo
# found san quintin
# Finished trying to get san quintin
# found oriximina
# Finished trying to get oriximina
# found yar-sale
# Finished trying to get yar-sale
# found ishigaki
# Finished trying to get ishigaki
# found ukiah
# Finished trying to get ukiah
# found cap-aux-meules
# Finished trying to get cap-aux-meules
# found pandan
# Finished trying to get pandan
# found srednekolymsk
# Finished trying to get srednekolymsk
# found codrington
# Finished trying to get codrington
# candawaga not found
# Something broke... 'coord'
# Finished trying to get candawaga
# found yinchuan
# Finished trying to get yinchuan
# found touros
# Finished trying to get touros
# found balykshi
# Finished trying to get balykshi
# agha jari not found
# Something broke... 'coord'
# Finished trying to get agha jari
# tingrela not found
# Something broke... 'coord'
# Finished trying to get tingrela
# found marystown
# Finished trying to get marystown
# found sergeyevka
# Finished trying to get sergeyevka
# found coos bay
# Finished trying to get coos bay
# found ohara
# Finished trying to get ohara
# found half moon bay
# Finished trying to get half moon bay
# found wake forest
# Finished trying to get wake forest
# found hearst
# Finished trying to get hearst
# found matagami
# Finished trying to get matagami
# found berbera
# Finished trying to get berbera
# found ardesen
# Finished trying to get ardesen
# found priiskovyy
# Finished trying to get priiskovyy
# kamenskoye not found
# Something broke... 'coord'
# Finished trying to get kamenskoye
# found challans
# Finished trying to get challans
# found dalhousie
# Finished trying to get dalhousie
# found loum
# Finished trying to get loum
# found nador
# Finished trying to get nador
# found ixtapa
# Finished trying to get ixtapa
# coetupo not found
# Something broke... 'coord'
# Finished trying to get coetupo
# found katsuura
# Finished trying to get katsuura
# found saint-pierre
# Finished trying to get saint-pierre
# found akalkot
# Finished trying to get akalkot
# found gboko
# Finished trying to get gboko
# found itum-kale
# Finished trying to get itum-kale
# found dezful
# Finished trying to get dezful
# babanusah not found
# Something broke... 'coord'
# Finished trying to get babanusah
# found morristown
# Finished trying to get morristown
# zolotinka not found
# Something broke... 'coord'
# Finished trying to get zolotinka
# found jiaocheng
# Finished trying to get jiaocheng
# found provideniya
# Finished trying to get provideniya
# found carutapera
# Finished trying to get carutapera
# found outlook
# Finished trying to get outlook
# found gadarwara
# Finished trying to get gadarwara
# found lieksa
# Finished trying to get lieksa
# found balti
# Finished trying to get balti
# found pervomayskoye
# Finished trying to get pervomayskoye
# found camacha
# Finished trying to get camacha
# found jeremie
# Finished trying to get jeremie
# found barsovo
# Finished trying to get barsovo
# found namatanai
# Finished trying to get namatanai
# found champoton
# Finished trying to get champoton
# paradwip not found
# Something broke... 'coord'
# Finished trying to get paradwip
# found marsaxlokk
# Finished trying to get marsaxlokk
# found pochutla
# Finished trying to get pochutla
# found kolpashevo
# Finished trying to get kolpashevo
# found guerrero negro
# Finished trying to get guerrero negro
# found kaduqli
# Finished trying to get kaduqli
# found charlestown
# Finished trying to get charlestown
# found hamilton
# Finished trying to get hamilton
# found tay ninh
# Finished trying to get tay ninh
# found peniche
# Finished trying to get peniche
# found basco
# Finished trying to get basco
# found sal rei
# Finished trying to get sal rei
# found high level
# Finished trying to get high level
# found xiongzhou
# Finished trying to get xiongzhou
# found stavern
# Finished trying to get stavern
# found anadyr
# Finished trying to get anadyr
# found san cristobal
# Finished trying to get san cristobal
# found aykhal
# Finished trying to get aykhal
# found sundsvall
# Finished trying to get sundsvall
# found nyaunglebin
# Finished trying to get nyaunglebin
# found sangar
# Finished trying to get sangar
# found lincoln
# Finished trying to get lincoln
# found leesburg
# Finished trying to get leesburg
# found usinsk
# Finished trying to get usinsk
# found abalak
# Finished trying to get abalak
# found batticaloa
# Finished trying to get batticaloa
# found giera
# Finished trying to get giera
# found los llanos de aridane
# Finished trying to get los llanos de aridane
# found coaticook
# Finished trying to get coaticook
# found yelovo
# Finished trying to get yelovo
# marv dasht not found
# Something broke... 'coord'
# Finished trying to get marv dasht
# found exeter
# Finished trying to get exeter
# found goderich
# Finished trying to get goderich
# found zaysan
# Finished trying to get zaysan
# found ryotsu
# Finished trying to get ryotsu
# found goure
# Finished trying to get goure
# found shingu
# Finished trying to get shingu
# found uzyn
# Finished trying to get uzyn
# found teguldet
# Finished trying to get teguldet
# found tatvan
# Finished trying to get tatvan
# found bording
# Finished trying to get bording
# found norden
# Finished trying to get norden
# found kodinsk
# Finished trying to get kodinsk
# found karpathos
# Finished trying to get karpathos
# found dakar
# Finished trying to get dakar
# borama not found
# Something broke... 'coord'
# Finished trying to get borama
# found kushmurun
# Finished trying to get kushmurun
# toftir not found
# Something broke... 'coord'
# Finished trying to get toftir
# found yuanlin
# Finished trying to get yuanlin
# found oistins
# Finished trying to get oistins
# found marshfield
# Finished trying to get marshfield
# found rapid valley
# Finished trying to get rapid valley
# found dustlik
# Finished trying to get dustlik
# found pemangkat
# Finished trying to get pemangkat
# found palasa
# Finished trying to get palasa
# found petatlan
# Finished trying to get petatlan
# found verkhnevilyuysk
# Finished trying to get verkhnevilyuysk
# artyk not found
# Something broke... 'coord'
# Finished trying to get artyk
# buariki not found
# Something broke... 'coord'
# Finished trying to get buariki
# found shieli
# Finished trying to get shieli
# found upata
# Finished trying to get upata
# found ust-tsilma
# Finished trying to get ust-tsilma
# found leh
# Finished trying to get leh
# found sinnamary
# Finished trying to get sinnamary
# found karlskrona
# Finished trying to get karlskrona
# found rimbey
# Finished trying to get rimbey
# found progreso
# Finished trying to get progreso
# found bardiyah
# Finished trying to get bardiyah
# found kaita
# Finished trying to get kaita
# found leninskoye
# Finished trying to get leninskoye
# found ljubinje
# Finished trying to get ljubinje
# tabulbah not found
# Something broke... 'coord'
# Finished trying to get tabulbah
# shchuchye not found
# Something broke... 'coord'
# Finished trying to get shchuchye
# found haines junction
# Finished trying to get haines junction
# found ketchikan
# Finished trying to get ketchikan
# found nanga eboko
# Finished trying to get nanga eboko
# found kemin
# Finished trying to get kemin
# found santa fe
# Finished trying to get santa fe
# found kushuhum
# Finished trying to get kushuhum
# found tres palos
# Finished trying to get tres palos
# found muhororo
# Finished trying to get muhororo
# found kyren
# Finished trying to get kyren
# azimur not found
# Something broke... 'coord'
# Finished trying to get azimur
# found severo-yeniseyskiy
# Finished trying to get severo-yeniseyskiy
# found nieuw amsterdam
# Finished trying to get nieuw amsterdam
# found agadir
# Finished trying to get agadir
# found coalinga
# Finished trying to get coalinga
# found idenao
# Finished trying to get idenao
# rawannawi not found
# Something broke... 'coord'
# Finished trying to get rawannawi
# found swiecie
# Finished trying to get swiecie
# found matara
# Finished trying to get matara
# found khartoum
# Finished trying to get khartoum
# found wetaskiwin
# Finished trying to get wetaskiwin
# found san jeronimito
# Finished trying to get san jeronimito
# vaitupu not found
# Something broke... 'coord'
# Finished trying to get vaitupu
# found pacific grove
# Finished trying to get pacific grove
# found payo
# Finished trying to get payo
# found ginda
# Finished trying to get ginda
# found mnogovershinnyy
# Finished trying to get mnogovershinnyy
# found lohardaga
# Finished trying to get lohardaga
# samusu not found
# Something broke... 'coord'
# Finished trying to get samusu
# found ust-uda
# Finished trying to get ust-uda
# found payakumbuh
# Finished trying to get payakumbuh
# uk not found
# Something broke... 'coord'
# Finished trying to get uk
# found pedernales
# Finished trying to get pedernales
# found ternate
# Finished trying to get ternate
# found khani
# Finished trying to get khani
# found kitimat
# Finished trying to get kitimat
# found nedjo
# Finished trying to get nedjo
# found luorong
# Finished trying to get luorong
# found freeport
# Finished trying to get freeport
# found gol
# Finished trying to get gol
# found vestmanna
# Finished trying to get vestmanna
# found asyut
# Finished trying to get asyut
# found rosarito
# Finished trying to get rosarito
# found muroto
# Finished trying to get muroto
# kazalinsk not found
# Something broke... 'coord'
# Finished trying to get kazalinsk
# found xichang
# Finished trying to get xichang
# found shrewsbury
# Finished trying to get shrewsbury
# found vanavara
# Finished trying to get vanavara
# found bilibino
# Finished trying to get bilibino
# found dukat
# Finished trying to get dukat
# found golcuv jenikov
# Finished trying to get golcuv jenikov
# found huilong
# Finished trying to get huilong
# found kidal
# Finished trying to get kidal
# found terrasini
# Finished trying to get terrasini
# found jauharabad
# Finished trying to get jauharabad
# found belen
# Finished trying to get belen
# found klamath falls
# Finished trying to get klamath falls
# found zhanaozen
# Finished trying to get zhanaozen
# found agadez
# Finished trying to get agadez
# found kamenka
# Finished trying to get kamenka
# found marzuq
# Finished trying to get marzuq
# found zhigalovo
# Finished trying to get zhigalovo
# found blankenberge
# Finished trying to get blankenberge
# found laukaa
# Finished trying to get laukaa
# asayita not found
# Something broke... 'coord'
# Finished trying to get asayita
# found gasa
# Finished trying to get gasa
# found muros
# Finished trying to get muros
# found visnes
# Finished trying to get visnes
# found irbeyskoye
# Finished trying to get irbeyskoye
# huazolotitlan not found
# Something broke... 'coord'
# Finished trying to get huazolotitlan
# found vermillion
# Finished trying to get vermillion
# found prince rupert
# Finished trying to get prince rupert
# found chodavaram
# Finished trying to get chodavaram
# found mata
# Finished trying to get mata
# found mykolayivka
# Finished trying to get mykolayivka
# found puerto escondido
# Finished trying to get puerto escondido
# found parrita
# Finished trying to get parrita
# found feldbach
# Finished trying to get feldbach
# found safaga
# Finished trying to get safaga
# found kutum
# Finished trying to get kutum
# found shenjiamen
# Finished trying to get shenjiamen
# found ust-nera
# Finished trying to get ust-nera
# found hibbing
# Finished trying to get hibbing
# found mirnyy
# Finished trying to get mirnyy
# found miles city
# Finished trying to get miles city
# found milkovo
# Finished trying to get milkovo
# found kawardha
# Finished trying to get kawardha
# found mabaruma
# Finished trying to get mabaruma
# found chebenki
# Finished trying to get chebenki
# katha not found
# Something broke... 'coord'
# Finished trying to get katha
# found maple creek
# Finished trying to get maple creek
# found anloga
# Finished trying to get anloga
# found masty
# Finished trying to get masty
# found khuzdar
# Finished trying to get khuzdar
# found pangnirtung
# Finished trying to get pangnirtung
# found wangqing
# Finished trying to get wangqing
# found hornepayne
# Finished trying to get hornepayne
# found sorland
# Finished trying to get sorland
# found tabuk
# Finished trying to get tabuk
# found almaznyy
# Finished trying to get almaznyy
# galgani not found
# Something broke... 'coord'
# Finished trying to get galgani
# found uray
# Finished trying to get uray
# found alghero
# Finished trying to get alghero
# maloshuyka not found
# Something broke... 'coord'
# Finished trying to get maloshuyka
# found gunjur
# Finished trying to get gunjur
# found khvorostyanka
# Finished trying to get khvorostyanka
# found meulaboh
# Finished trying to get meulaboh
# found saravena
# Finished trying to get saravena
# found manokwari
# Finished trying to get manokwari
# found muyezerskiy
# Finished trying to get muyezerskiy
# found levelek
# Finished trying to get levelek
# found kapit
# Finished trying to get kapit
# found constitucion
# Finished trying to get constitucion
# found nizwa
# Finished trying to get nizwa
# found wynyard
# Finished trying to get wynyard
# found buchanan
# Finished trying to get buchanan
# found jijiga
# Finished trying to get jijiga
# almiros not found
# Something broke... 'coord'
# Finished trying to get almiros
# found gerede
# Finished trying to get gerede
# found champerico
# Finished trying to get champerico
# found santa barbara
# Finished trying to get santa barbara
# found shiyan
# Finished trying to get shiyan
# found thunder bay
# Finished trying to get thunder bay
# found channel-port aux basques
# Finished trying to get channel-port aux basques
# found bosaso
# Finished trying to get bosaso
# found tahe
# Finished trying to get tahe
# found bisira
# Finished trying to get bisira
# found bukachacha
# Finished trying to get bukachacha
# found keti bandar
# Finished trying to get keti bandar
# found udachnyy
# Finished trying to get udachnyy
# found vigia del fuerte
# Finished trying to get vigia del fuerte
# found atasu
# Finished trying to get atasu
# found karaton
# Finished trying to get karaton
# found inirida
# Finished trying to get inirida
# pousat not found
# Something broke... 'coord'
# Finished trying to get pousat
# found phatthalung
# Finished trying to get phatthalung
# found gidole
# Finished trying to get gidole
# found xuddur
# Finished trying to get xuddur
# found murmashi
# Finished trying to get murmashi
# found volnovakha
# Finished trying to get volnovakha
# found tiznit
# Finished trying to get tiznit
# found sorong
# Finished trying to get sorong
# found amalapuram
# Finished trying to get amalapuram
# mme not found
# Something broke... 'coord'
# Finished trying to get mme
# found muli
# Finished trying to get muli
# found kuloy
# Finished trying to get kuloy
# found evinayong
# Finished trying to get evinayong
# solovetskiy not found
# Something broke... 'coord'
# Finished trying to get solovetskiy
# found dindori
# Finished trying to get dindori
# found kohlu
# Finished trying to get kohlu
# found ola
# Finished trying to get ola
# found nara
# Finished trying to get nara
# found alikalia
# Finished trying to get alikalia
# found lahaina
# Finished trying to get lahaina
# found eureka
# Finished trying to get eureka
# found neryungri
# Finished trying to get neryungri
# found raga
# Finished trying to get raga
# found huntsville
# Finished trying to get huntsville
# found hede
# Finished trying to get hede
# found oussouye
# Finished trying to get oussouye
# found am timan
# Finished trying to get am timan
# found zaranj
# Finished trying to get zaranj
# found shimanovsk
# Finished trying to get shimanovsk
# found gigmoto
# Finished trying to get gigmoto
# found athens
# Finished trying to get athens
# found soldato-aleksandrovskoye
# Finished trying to get soldato-aleksandrovskoye
# found batagay-alyta
# Finished trying to get batagay-alyta
# found painesville
# Finished trying to get painesville
# found clonakilty
# Finished trying to get clonakilty
# found sinegorye
# Finished trying to get sinegorye
# found tarko-sale
# Finished trying to get tarko-sale
# found coahuayana
# Finished trying to get coahuayana
# found darnah
# Finished trying to get darnah
# found mogzon
# Finished trying to get mogzon
# found kenai
# Finished trying to get kenai
# found sturgeon bay
# Finished trying to get sturgeon bay
# found lebork
# Finished trying to get lebork
# ust-kamchatsk not found
# Something broke... 'coord'
# Finished trying to get ust-kamchatsk
# found birao
# Finished trying to get birao
# malwan not found
# Something broke... 'coord'
# Finished trying to get malwan
# found kungurtug
# Finished trying to get kungurtug
# found tema
# Finished trying to get tema
# found maumelle
# Finished trying to get maumelle
# found ilanskiy
# Finished trying to get ilanskiy
# found calituban
# Finished trying to get calituban
# found berezovyy
# Finished trying to get berezovyy
# found elizabethton
# Finished trying to get elizabethton
# found tateyama
# Finished trying to get tateyama
# found tilichiki
# Finished trying to get tilichiki
# velikie luki not found
# Something broke... 'coord'
# Finished trying to get velikie luki
# found cedar lake
# Finished trying to get cedar lake
# found tigil
# Finished trying to get tigil
# found najran
# Finished trying to get najran
# found tashla
# Finished trying to get tashla
# barawe not found
# Something broke... 'coord'
# Finished trying to get barawe
# sorvag not found
# Something broke... 'coord'
# Finished trying to get sorvag
# found yalutorovsk
# Finished trying to get yalutorovsk
# found kuybyshevo
# Finished trying to get kuybyshevo
# found lazaro cardenas
# Finished trying to get lazaro cardenas
# found mehran
# Finished trying to get mehran
# found anklam
# Finished trying to get anklam
# found aksarka
# Finished trying to get aksarka
# found epinal
# Finished trying to get epinal
# found serebryansk
# Finished trying to get serebryansk
# found hammerfest
# Finished trying to get hammerfest
# found galveston
# Finished trying to get galveston
# found tramore
# Finished trying to get tramore
# found yongzhou
# Finished trying to get yongzhou
# found millinocket
# Finished trying to get millinocket
# found tambura
# Finished trying to get tambura
# found xiongyue
# Finished trying to get xiongyue
# found forest grove
# Finished trying to get forest grove
# found alenquer
# Finished trying to get alenquer
# found yashkino
# Finished trying to get yashkino
# found ekhabi
# Finished trying to get ekhabi
# found black forest
# Finished trying to get black forest
# found steamboat springs
# Finished trying to get steamboat springs
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-687ee7014d4f> in <module>
#      21         print('Finished trying to get', city)
#      22
# ---> 23 city_name.to_csv("./output/cities.csv", index=False)
#
# AttributeError: 'list' object has no attribute 'to_csv'

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Set up a df by using dict. They are defined in the list above.
weather_df = DataFrame({
    'City_Name': city_name,
    'Temp': temp,
    'Latitude': lats,
    'Longitude': lngs,
    'Humidity': humidity,
    'Wind_Speed': wind_speed,
    'Cloudiness': cloudiness,
})

# %%
weather_df
# type(weather_df)  # Check it is a df of type
# Out:
#              City_Name   Temp  Latitude  Longitude  Humidity  Wind_Speed  \
# 0             sisimiut  36.19   66.9395   -53.6735        82        7.90
# 1                  sur  92.62   22.5667    59.5289        32       14.54
# 2              mandera  76.62    3.9366    41.8670        67       15.93
# 3               hasaki  68.58   35.7333   140.8333        71        6.35
# 4              pangody  41.97   65.8500    74.4859        53        8.10
# ..                 ...    ...       ...        ...       ...         ...
# 649           alenquer  79.14   -1.9417   -54.7383        77        3.98
# 650           yashkino  54.55   55.8736    85.4265        61        4.25
# 651             ekhabi  45.36   53.5102   142.9671        64       10.00
# 652       black forest  47.77   39.0131  -104.7008       100        3.44
# 653  steamboat springs  63.73   40.4850  -106.8317        39        3.44
#
#      Cloudiness
# 0            61
# 1            36
# 2            72
# 3            80
# 4            10
# ..          ...
# 649          79
# 650           9
# 651         100
# 652          75
# 653          90
#
# [654 rows x 7 columns]

# %%
# Export the city data into a .csv file in the output folder
weather_df.to_csv("./output/weather_data.csv", index=False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df['Latitude'], weather_df['Temp'])
plt.title(f"Latitude of City vs Current Temperature")
plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Current Temperature')
plt.savefig("./output/lat_vs_temp.png", bbox_inches="tight")
plt.show()

# Analysis:  There is a direct correlation of temperature relative to the equator (Latitude = 0).  
# The closer the city is to the equator, the higher the temperature.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df['Latitude'], weather_df['Humidity'])
plt.title(f"Latitude of City vs Current Humidity")
plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Current Humidity')
plt.savefig("./output/lat_vs_humidity.png", bbox_inches="tight")
plt.show()

# Analysis:  In analyzing humidity relative to latitude, it is fairly distributed.  
# That means high humidity can be found in cities near or far from the equator (Latitude = 0).

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df['Latitude'], weather_df['Cloudiness'])
plt.title(f"Latitude of City vs Current Cloudiness")
plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Current Cloudiness')
plt.savefig("./output/lat_vs_cloud.png", bbox_inches="tight")
plt.show()

# Analysis:  In the analysis of cloudiness relative to latitude, it is distributed.  
# That means cloudiness found in cities is not related to the distance of the cities to equator (Latitude = 0).

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df['Humidity'], weather_df['Wind_Speed'])
plt.title(f"Latitude of City vs Current Wind Speed")
plt.grid(True)
plt.xlabel('Latitude')
plt.ylabel('Current Wind Speed')
plt.savefig("./output/lat_vs_wind.png", bbox_inches="tight")
plt.show()

# Analysis:  In the analysis of cloudiness relative to latitude, there appears to be a correlation of higher wind speeds 
# to the further away the city is from the equator (Latitude = 0).

# %% [markdown]
# ## Linear Regression

# %%
# Define the criterias for Northern and Southern Hemisphere.  Use .loc method in a list.  Create new dataframes.
northern_hemp_df = weather_df.loc[weather_df['Latitude'] >= 0]
southern_hemp_df = weather_df.loc[weather_df['Latitude'] < 0]

# %%
# Create a scatter plot for latitude vs max temp (northern hemisphere)
#x_values = northern_hemp_df['Latitude']
#y_values = northern_hemp_df['Temp']

#plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
